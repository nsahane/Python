# %% [markdown]
# **DataFrame Assignment**

# %%
import pandas as pd

# %%
data = pd.DataFrame({"Name":['Avery Bradley','John Holland','Jonas Jerebko','Jorden mickey','Terry Rozier','Jared Sullinger','Evan Tucner'],
                    "Team":['Boston Celtics','Boston Celtics','Boston Celtics','Boston Celtics','Boston Celtics','Boston Celtics','Boston Celtics'],
                    "Number":[0.0,30.0,8.0,"nan",12.0,7.0,11.0],
                    "Position":['PG','SG','PF','PF','PG','C','SG'],
                    "Age":[25.0,27.0,29.0,21.0,22.0,"nan",27.0]})

# %%
data
# Out:
#               Name            Team Number Position   Age
# 0    Avery Bradley  Boston Celtics    0.0       PG  25.0
# 1     John Holland  Boston Celtics   30.0       SG  27.0
# 2    Jonas Jerebko  Boston Celtics    8.0       PF  29.0
# 3    Jorden mickey  Boston Celtics    nan       PF  21.0
# 4     Terry Rozier  Boston Celtics   12.0       PG  22.0
# 5  Jared Sullinger  Boston Celtics    7.0        C   nan
# 6      Evan Tucner  Boston Celtics   11.0       SG  27.0

# %%
data.head()
# Out:
#             Name            Team Number Position   Age
# 0  Avery Bradley  Boston Celtics    0.0       PG  25.0
# 1   John Holland  Boston Celtics   30.0       SG  27.0
# 2  Jonas Jerebko  Boston Celtics    8.0       PF  29.0
# 3  Jorden mickey  Boston Celtics    nan       PF  21.0
# 4   Terry Rozier  Boston Celtics   12.0       PG  22.0

# %%
data.tail()
# Out:
#               Name            Team Number Position   Age
# 2    Jonas Jerebko  Boston Celtics    8.0       PF  29.0
# 3    Jorden mickey  Boston Celtics    nan       PF  21.0
# 4     Terry Rozier  Boston Celtics   12.0       PG  22.0
# 5  Jared Sullinger  Boston Celtics    7.0        C   nan
# 6      Evan Tucner  Boston Celtics   11.0       SG  27.0

# %%
data.size
# Out:
# 35

# %%
data.shape
# Out:
# (7, 5)

# %%
data.columns
# Out:
# Index(['Name', 'Team', 'Number', 'Position', 'Age'], dtype='object')

# %%
len(data)
# Out:
# 7

# %%
data.index
# Out:
# RangeIndex(start=0, stop=7, step=1)

# %%
data.dtypes
# Out:
# Name        object
# Team        object
# Number      object
# Position    object
# Age         object
# dtype: object

# %%
data.values
# Out:
# array([['Avery Bradley', 'Boston Celtics', 0.0, 'PG', 25.0],
#        ['John Holland', 'Boston Celtics', 30.0, 'SG', 27.0],
#        ['Jonas Jerebko', 'Boston Celtics', 8.0, 'PF', 29.0],
#        ['Jorden mickey', 'Boston Celtics', 'nan', 'PF', 21.0],
#        ['Terry Rozier', 'Boston Celtics', 12.0, 'PG', 22.0],
#        ['Jared Sullinger', 'Boston Celtics', 7.0, 'C', 'nan'],
#        ['Evan Tucner', 'Boston Celtics', 11.0, 'SG', 27.0]], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      7 non-null      object
#  1   Team      7 non-null      object
#  2   Number    7 non-null      object
#  3   Position  7 non-null      object
#  4   Age       7 non-null      object
# dtypes: object(5)
# memory usage: 408.0+ bytes

# %%
data.describe()
# Out:
#                  Name            Team  Number Position   Age
# count               7               7     7.0        7   7.0
# unique              7               1     7.0        4   6.0
# top     Avery Bradley  Boston Celtics     0.0       PG  27.0
# freq                1               7     1.0        2   2.0

# %%
data["Name"]
# Out:
# 0      Avery Bradley
# 1       John Holland
# 2      Jonas Jerebko
# 3      Jorden mickey
# 4       Terry Rozier
# 5    Jared Sullinger
# 6        Evan Tucner
# Name: Name, dtype: object

# %%
data[["Age",'Team','Number']]
# Out:
#     Age            Team Number
# 0  25.0  Boston Celtics    0.0
# 1  27.0  Boston Celtics   30.0
# 2  29.0  Boston Celtics    8.0
# 3  21.0  Boston Celtics    nan
# 4  22.0  Boston Celtics   12.0
# 5   nan  Boston Celtics    7.0
# 6  27.0  Boston Celtics   11.0

# %%
data.query('Name=="Avery Bradley"')
# Out:
#             Name            Team Number Position   Age
# 0  Avery Bradley  Boston Celtics    0.0       PG  25.0

# %%
data.query('Age > 25.0')
# Out:
#             Name            Team Number Position   Age
# 1   John Holland  Boston Celtics   30.0       SG  27.0
# 2  Jonas Jerebko  Boston Celtics    8.0       PF  29.0
# 6    Evan Tucner  Boston Celtics   11.0       SG  27.0

# %%
data.query('Name=="Avery Bradley" & Age==25.0')
# Out:
#             Name            Team Number Position   Age
# 0  Avery Bradley  Boston Celtics    0.0       PG  25.0

# %%
data[data.Name.str.startswith('J')]
# Out:
#               Name            Team Number Position   Age
# 1     John Holland  Boston Celtics   30.0       SG  27.0
# 2    Jonas Jerebko  Boston Celtics    8.0       PF  29.0
# 3    Jorden mickey  Boston Celtics    nan       PF  21.0
# 5  Jared Sullinger  Boston Celtics    7.0        C   nan

# %%
data[data['Age'] > 25.0]
# Out:
#             Name            Team Number Position   Age
# 1   John Holland  Boston Celtics   30.0       SG  27.0
# 2  Jonas Jerebko  Boston Celtics    8.0       PF  29.0
# 6    Evan Tucner  Boston Celtics   11.0       SG  27.0

# %%
data[data.Name.str.startswith('J')]
# Out:
#               Name            Team Number Position   Age
# 1     John Holland  Boston Celtics   30.0       SG  27.0
# 2    Jonas Jerebko  Boston Celtics    8.0       PF  29.0
# 3    Jorden mickey  Boston Celtics    nan       PF  21.0
# 5  Jared Sullinger  Boston Celtics    7.0        C   NaN

# %%
data[data.Name.str.endswith('r')]
# Out:
#               Name            Team Number Position   Age
# 4     Terry Rozier  Boston Celtics   12.0       PG  22.0
# 5  Jared Sullinger  Boston Celtics    7.0        C   NaN
# 6      Evan Tucner  Boston Celtics   11.0       SG  27.0

# %%
pd.value_counts(data["Name"])
# Out:
# <ipython-input-78-c664fe5c0a25>:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(data["Name"])
# Name
# Avery Bradley      1
# John Holland       1
# Jonas Jerebko      1
# Jorden mickey      1
# Terry Rozier       1
# Jared Sullinger    1
# Evan Tucner        1
# Name: count, dtype: int64

# %%
pd.value_counts(data["Position"])
# Out:
# <ipython-input-81-c7a88bec74c6>:1: FutureWarning: pandas.value_counts is deprecated and will be removed in a future version. Use pd.Series(obj).value_counts() instead.
#   pd.value_counts(data["Position"])
# Position
# PG    2
# SG    2
# PF    2
# C     1
# Name: count, dtype: int64
